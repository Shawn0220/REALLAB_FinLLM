# %%
import os
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# %%
import os
from autogen import AssistantAgent, UserProxyAgent, GroupChat, GroupChatManager
from openai import OpenAI


  # It will automatically pick up the env var
llm_config = {
    "config_list": [
        {
            "model": "gpt-4",
            # "api_type": "azure",
            "api_key": OPENAI_API_KEY
            # "base_url": "https://hw2aiservices.openai.azure.com/",
            # "api_version": "2024-05-13",
        }
    ]
}

def get_last_reply_from(cur_agent):
    # get cur_agent's last reply to others
    for msg_list in cur_agent.chat_messages.values():
        for msg in reversed(msg_list):  # 从后往前找
            if msg.get("role") == "assistant" and msg.get("name") == cur_agent.name:
                return msg["content"]
    return None

def print_agent_chat_history(agent):
    print(f"\n--- Chat history for agent: {agent.name} ---")
    for msg in agent.chat_messages:
        # 安全提取 sender
        print(msg)
        # sender_raw = msg.get("name", "Unknown")
        # sender = sender_raw.name if hasattr(sender_raw, "name") else str(sender_raw)
        
        # content = msg.get("content", "")
        # print(f"{sender} ➜ {agent.name}: {content}\n")

class SpokespersonAgent(AssistantAgent):
    pass

class RecommenderAgent(AssistantAgent):
    pass

class CompletenessCheckAgent(AssistantAgent):
    pass

# %%
spokesperson_agent = SpokespersonAgent(
    name="spokesperson_agent",
    llm_config=llm_config,
    system_message="""
    You are the spokesperson of the research team. Your job is to assess the trader's decision and evaluate whether it sufficiently considers the team's prior Bullish and Bearish arguments.
    
    If you think the trader's response reflects the team's views, say:
    "TERMINATE. Your decision reflects our team's analysis. You may stop here."

    Otherwise, ask for clarification or adjustment.
    """
)

# %%
spokesperson_agent = SpokespersonAgent(
    name="spokesperson_agent",
    llm_config=llm_config,
    system_message="""
    You are the spokesperson of the research team. Your job is to assess the trader's decision and evaluate whether it sufficiently considers the team's prior Bullish and Bearish arguments.
    
    If you think the trader's response reflects the team's views, say:
    "TERMINATE. Your decision reflects our team's analysis. You may stop here."

    Otherwise, ask for clarification or adjustment.
    """
)

trade_recommender_agent = RecommenderAgent(
    name="trade_recommender_agent",
    llm_config=llm_config,
    system_message="""
    You are the delivering Trader's decision to risk team
    whatever they say, just reply:
    "TERMINATE"
    """
)

completeness_check_agent = CompletenessCheckAgent(
    name="completeness_check_agent",
    llm_config=llm_config,
    system_message="""
    You are the checking manager_agent's decision
    if they give certain decision in EXECUTE_TRADE or DO_NOT_EXECUTE, reply:
    "FINISHED"
    """
)

class TraderAgentWithTermination(AssistantAgent):
    def is_termination_msg(self, message):
        # 只要包含 BUY 或 SELL 就终止
        content = message.get("content", "").lower()
        return "buy" in content or "sell" in content


# === Mock function for stock data collection ===
def data_collect(stock_name):
    return {
        "company_info": f"{stock_name} is a tech company founded in 2005.",
        "stock_price_history": [120, 123, 119, 125, 130],
        "social_media_sentiment": "Mixed, trending positive."
    }

# === Analyst Agent ===
analyst_agent = AssistantAgent(
    name="analyst_agent",
    llm_config=llm_config,
    system_message="""
    You are a market data analyst. You are allowed to call data_collect(stock_name) to gather information.
    Do NOT make investment decisions. Simply output the result of data_collect().
    """
)

# === Bullish Research Agent ===
bullish_agent = AssistantAgent(
    name="bullish_research_agent",
    llm_config=llm_config,
    system_message="""
    You are an optimistic stock researcher. Your job is to analyze data and argue why the stock is a good investment.
    You do not consider risks or negative sentiment. Your goal is to convince others the stock should be bought.
    """
)

# === Bearish Research Agent ===
bearish_agent = AssistantAgent(
    name="bearish_research_agent",
    llm_config=llm_config,
    system_message="""
    You are a conservative stock researcher. Your job is to analyze data and argue why the stock is risky or not a good investment.
    Your goal is to point out why the stock should be avoided.
    """
)

# === Trader Agent ===
trader_agent = AssistantAgent(
    name="trader_agent",
    llm_config=llm_config,
    system_message="""
    You are a trader. You read the bullish and bearish arguments and make a BUY or SELL suggestion.
    Do NOT consider risk preference.
    Just focus on the quality of the arguments and market outlook.
    Output your recommendation as: BUY or SELL and a short justification.
    """,
    is_termination_msg=lambda msg: "terminate" in msg.get("content", "").lower()
)


# === RRisk Management Team Agent ===
# risk_profile = os.getenv("RISK_PROFILE", "Neutral")
risk_profile = "Neutral"

risk_manager_agent = AssistantAgent(
    name="risk_manager_agent",
    llm_config=llm_config,
    system_message=f"""
    You are Risk Management Team. Current risk preference is: {risk_profile}.
    You evaluate trader's suggestion and tag it as Aggressive, Neutral, or Conservative.
    You can approve or reject the trade suggestion based on risk alignment.
    Only output one of these: APPROVED (with tag), or REJECTED (with reason).
    """,
    is_termination_msg=lambda msg: "terminate" in msg.get("content", "").lower()
)

# === Manager Agent ===
manager_agent = AssistantAgent(
    name="manager_agent",
    llm_config=llm_config,
    system_message="""
    You are the manager. You make the final decision to execute the trade.
    Your output should include EXECUTE_TRADE or DO_NOT_EXECUTE and give reasons.
    """,
    is_termination_msg=lambda msg: "finished" in msg.get("content", "").lower()
)

# === User Proxy Agent to initiate the workflow ===
user_proxy = UserProxyAgent(
    name="user_proxy_agent",
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: msg.get("content") is not None and "TERMINATE" in msg["content"],
    code_execution_config={"use_docker": False}
    )

# === Group chat for Bullish/Bearish debate ===
debate_group = GroupChat(
    agents=[bullish_agent, bearish_agent],
    messages=[],
    max_round=3,
    speaker_selection_method="round_robin"
)
debate_manager = GroupChatManager(groupchat=debate_group)

# === Main Orchestration Function ===
def run_stock_recommendation(stock_name):
    print("\n=== Step 1: Analyst collects data ===")
    stock_data = data_collect(stock_name)
    print("Data Collected:", stock_data)

    stock_data_str = (
        f"Stock Name: {stock_name}\n\n"
        f"Company Info: {stock_data['company_info']}\n"
        f"Stock Price History: {stock_data['stock_price_history']}\n"
        f"Social Media Sentiment: {stock_data['social_media_sentiment']}\n"
    )

    print("\n=== Step 2: Bullish vs Bearish debate ===")
    user_proxy.initiate_chat(debate_manager, message=f"The following stock data is available:\n{stock_data_str}")

    debate_summary = "\n--- Debate Summary ---\n"
    for msg in debate_group.messages:
        debate_summary += f"{msg['name']}: {msg['content']}\n"

    print("\n=== Step 3: Trader makes a decision ===")
    trader_prompt = (
        f"{stock_data_str}\n"
        f"{debate_summary}\n"
        "Based on the above, please make a BUY or SELL decision with reasoning.\n"
    )
    

    spokesperson_agent.initiate_chat(trader_agent, message=trader_prompt)

    trader_agent_response = get_last_reply_from(trader_agent)
    # trader_agent_response = user_proxy.initiate_chat(trader_agent, message=trader_prompt)

    # print("********************************")
    # print(trader_agent_response)
    # print("********************************")


    print("\n=== Step 4: Risk Management Team reviews ===")
    risk_prompt = (
        f"{stock_data_str}\n\n"
        f"{debate_summary}\n"
        f"Trader's Decision:\n{trader_agent_response}\n\n"
        f"Current Risk Profile: {risk_profile}\n"
        "Evaluate if this decision aligns with risk preferences. Approve or reject."
    )
    trade_recommender_agent.initiate_chat(risk_manager_agent, message=risk_prompt)
    

    risk_decision = get_last_reply_from(risk_manager_agent)

    print("\n=== Step 5: Manager final decision ===")
    manager_prompt = (
        f"{stock_data_str}\n\n"
        f"{debate_summary}\n"
        f"Trader's Decision:\n{trader_agent_response}\n\n"
        f"Risk Management Team's Decision:\n{risk_decision}\n\n"
        "Should we execute the trade?"
    )
    completeness_check_agent.initiate_chat(manager_agent, message=manager_prompt)


# === Example Usage ===
if __name__ == "__main__":
    run_stock_recommendation("TSLA")
# Out:
# === Step 1: Analyst collects data ===
# Data Collected: {'company_info': 'TSLA is a tech company founded in 2005.', 'stock_price_history': [120, 123, 119, 125, 130], 'social_media_sentiment': 'Mixed, trending positive.'}
#
# === Step 2: Bullish vs Bearish debate ===
# user_proxy_agent (to chat_manager):
#
# The following stock data is available:
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: bullish_research_agent
#
# bullish_research_agent (to chat_manager):
#
# Investing in TSLA (Tesla) would be an optimistic move for several reasons. The first one is that TSLA's stock price has continuously risen, based on its historical data. The figures moved from $120 to a peak of $130, reflecting substantial growth potential. This enhancement in the stock price reflects a strong upward trend, pointing to a promising future for investors.
#
# Moreover, TSLA is a renowned tech company and it's in a booming industry. The company was founded in 2005, which tells us it has weathered the different economic climates and survived, pointing towards a solid business model and good management. It is also important to note that being in the tech industry, it stands at the forefront of innovation which can potentially hold attractive future prospects.
#
# In terms of social media sentiment, although it is mixed, it is trending positive. This showcases public confidence in the company's activities and outlook. Positive social media sentiment is often a precursor to boosted stock performance. As more and more people discuss the benefits and potential of TSLA, it could attract new investors, which in turn can help push the stock price further up.
#
# In conclusion, based on its upwardly trending stock price, solid industry position and positive market sentiment, TSLA squarely deserves to be considered for investment.
#
# --------------------------------------------------------------------------------
#
# Next speaker: bearish_research_agent
#
# bearish_research_agent (to chat_manager):
#
# While it is true that Tesla's (TSLA) stock has shown growth over time, we should caution against viewing this particular pattern as an indicator of future performance. The recent increase, from $120 to $130, may simply be a part of short-term fluctuations rather than a consistent pattern of growth which can lead to unsustainable valuations.
#
# Additionally, while Tesla is a recognized entity in the technology industry, it is also part of the highly competitive and quickly evolving electric vehicle market. Their success is dependent on continual innovations and updates, an area fraught with uncertainties. Therefore, the need to stay ahead of competition can result in significant R&D costs which could affect future profitability.
#
# The mixed social media sentiments suggest a divided public opinion towards the company's prospects. While it may be trending positively now, the volatile nature of social media sentiment means this could quickly change and impact the stock's performance.
#
# While Tesla has a history of resilience, it should not be overlooked that they operate in a sector marked by rapid technological change, strict regulatory requirements and substantial capital demands. All these factors combined make TSLA a high risk investment.
#
# In conclusion, while the recent performance and positive sentiment may seem enticing, investors should remain cautious due to the risk factors associated with technological dependency, harsh competition, and unpredictable social media sentiment. It is crucial for potential investors to do a thorough analysis considering all factors before making a decision based on short-term growth trends.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (86b2e557-6406-4715-bc49-7ae2dae645a8): Maximum rounds (3) reached
#
# === Step 3: Trader makes a decision ===
# spokesperson_agent (to trader_agent):
#
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
#
# --- Debate Summary ---
# user_proxy_agent: The following stock data is available:
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
# bullish_research_agent: Investing in TSLA (Tesla) would be an optimistic move for several reasons. The first one is that TSLA's stock price has continuously risen, based on its historical data. The figures moved from $120 to a peak of $130, reflecting substantial growth potential. This enhancement in the stock price reflects a strong upward trend, pointing to a promising future for investors.
#
# Moreover, TSLA is a renowned tech company and it's in a booming industry. The company was founded in 2005, which tells us it has weathered the different economic climates and survived, pointing towards a solid business model and good management. It is also important to note that being in the tech industry, it stands at the forefront of innovation which can potentially hold attractive future prospects.
#
# In terms of social media sentiment, although it is mixed, it is trending positive. This showcases public confidence in the company's activities and outlook. Positive social media sentiment is often a precursor to boosted stock performance. As more and more people discuss the benefits and potential of TSLA, it could attract new investors, which in turn can help push the stock price further up.
#
# In conclusion, based on its upwardly trending stock price, solid industry position and positive market sentiment, TSLA squarely deserves to be considered for investment.
# bearish_research_agent: While it is true that Tesla's (TSLA) stock has shown growth over time, we should caution against viewing this particular pattern as an indicator of future performance. The recent increase, from $120 to $130, may simply be a part of short-term fluctuations rather than a consistent pattern of growth which can lead to unsustainable valuations.
#
# Additionally, while Tesla is a recognized entity in the technology industry, it is also part of the highly competitive and quickly evolving electric vehicle market. Their success is dependent on continual innovations and updates, an area fraught with uncertainties. Therefore, the need to stay ahead of competition can result in significant R&D costs which could affect future profitability.
#
# The mixed social media sentiments suggest a divided public opinion towards the company's prospects. While it may be trending positively now, the volatile nature of social media sentiment means this could quickly change and impact the stock's performance.
#
# While Tesla has a history of resilience, it should not be overlooked that they operate in a sector marked by rapid technological change, strict regulatory requirements and substantial capital demands. All these factors combined make TSLA a high risk investment.
#
# In conclusion, while the recent performance and positive sentiment may seem enticing, investors should remain cautious due to the risk factors associated with technological dependency, harsh competition, and unpredictable social media sentiment. It is crucial for potential investors to do a thorough analysis considering all factors before making a decision based on short-term growth trends.
#
# Based on the above, please make a BUY or SELL decision with reasoning.
#
#
# --------------------------------------------------------------------------------
# trader_agent (to spokesperson_agent):
#
# BUY
#
# The bullish argument presents strong points for considering an investment in Tesla (TSLA). The continuous growth in stock price is encouraging and a sign of good management and a promising future. While the bearish argument cautions against uncertainty due to the nature of the tech business and the volatility of social sentiments, it does not provide solid evidence of imminent declines or issues that could affect TSLA's current performance significantly. The positive trend in social media sentiment, while not a concrete indicator in itself, can contribute to potential investors' confidence. Therefore, if we consider the factors at hand, the bullish argument to continue investing in TSLA is stronger.
#
# --------------------------------------------------------------------------------
# spokesperson_agent (to trader_agent):
#
# TERMINATE. Your decision reflects our team's analysis. You may stop here.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (5e77ca10-f172-4f9b-a3de-762724e71d79): Termination message condition on agent 'trader_agent' met
#
# === Step 4: Risk Management Team reviews ===
# trade_recommender_agent (to risk_manager_agent):
#
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
#
#
# --- Debate Summary ---
# user_proxy_agent: The following stock data is available:
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
# bullish_research_agent: Investing in TSLA (Tesla) would be an optimistic move for several reasons. The first one is that TSLA's stock price has continuously risen, based on its historical data. The figures moved from $120 to a peak of $130, reflecting substantial growth potential. This enhancement in the stock price reflects a strong upward trend, pointing to a promising future for investors.
#
# Moreover, TSLA is a renowned tech company and it's in a booming industry. The company was founded in 2005, which tells us it has weathered the different economic climates and survived, pointing towards a solid business model and good management. It is also important to note that being in the tech industry, it stands at the forefront of innovation which can potentially hold attractive future prospects.
#
# In terms of social media sentiment, although it is mixed, it is trending positive. This showcases public confidence in the company's activities and outlook. Positive social media sentiment is often a precursor to boosted stock performance. As more and more people discuss the benefits and potential of TSLA, it could attract new investors, which in turn can help push the stock price further up.
#
# In conclusion, based on its upwardly trending stock price, solid industry position and positive market sentiment, TSLA squarely deserves to be considered for investment.
# bearish_research_agent: While it is true that Tesla's (TSLA) stock has shown growth over time, we should caution against viewing this particular pattern as an indicator of future performance. The recent increase, from $120 to $130, may simply be a part of short-term fluctuations rather than a consistent pattern of growth which can lead to unsustainable valuations.
#
# Additionally, while Tesla is a recognized entity in the technology industry, it is also part of the highly competitive and quickly evolving electric vehicle market. Their success is dependent on continual innovations and updates, an area fraught with uncertainties. Therefore, the need to stay ahead of competition can result in significant R&D costs which could affect future profitability.
#
# The mixed social media sentiments suggest a divided public opinion towards the company's prospects. While it may be trending positively now, the volatile nature of social media sentiment means this could quickly change and impact the stock's performance.
#
# While Tesla has a history of resilience, it should not be overlooked that they operate in a sector marked by rapid technological change, strict regulatory requirements and substantial capital demands. All these factors combined make TSLA a high risk investment.
#
# In conclusion, while the recent performance and positive sentiment may seem enticing, investors should remain cautious due to the risk factors associated with technological dependency, harsh competition, and unpredictable social media sentiment. It is crucial for potential investors to do a thorough analysis considering all factors before making a decision based on short-term growth trends.
#
# Trader's Decision:
# BUY
#
# The bullish argument presents strong points for considering an investment in Tesla (TSLA). The continuous growth in stock price is encouraging and a sign of good management and a promising future. While the bearish argument cautions against uncertainty due to the nature of the tech business and the volatility of social sentiments, it does not provide solid evidence of imminent declines or issues that could affect TSLA's current performance significantly. The positive trend in social media sentiment, while not a concrete indicator in itself, can contribute to potential investors' confidence. Therefore, if we consider the factors at hand, the bullish argument to continue investing in TSLA is stronger.
#
# Current Risk Profile: Neutral
# Evaluate if this decision aligns with risk preferences. Approve or reject.
#
# --------------------------------------------------------------------------------
# risk_manager_agent (to trade_recommender_agent):
#
# APPROVED (Neutral)
#
# --------------------------------------------------------------------------------
# trade_recommender_agent (to risk_manager_agent):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (94218cbe-8c2f-44dd-a180-b5ad35b8a661): Termination message condition on agent 'risk_manager_agent' met
#
# === Step 5: Manager final decision ===
# trade_recommender_agent (to manager_agent):
#
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
#
#
# --- Debate Summary ---
# user_proxy_agent: The following stock data is available:
# Stock Name: TSLA
#
# Company Info: TSLA is a tech company founded in 2005.
# Stock Price History: [120, 123, 119, 125, 130]
# Social Media Sentiment: Mixed, trending positive.
#
# bullish_research_agent: Investing in TSLA (Tesla) would be an optimistic move for several reasons. The first one is that TSLA's stock price has continuously risen, based on its historical data. The figures moved from $120 to a peak of $130, reflecting substantial growth potential. This enhancement in the stock price reflects a strong upward trend, pointing to a promising future for investors.
#
# Moreover, TSLA is a renowned tech company and it's in a booming industry. The company was founded in 2005, which tells us it has weathered the different economic climates and survived, pointing towards a solid business model and good management. It is also important to note that being in the tech industry, it stands at the forefront of innovation which can potentially hold attractive future prospects.
#
# In terms of social media sentiment, although it is mixed, it is trending positive. This showcases public confidence in the company's activities and outlook. Positive social media sentiment is often a precursor to boosted stock performance. As more and more people discuss the benefits and potential of TSLA, it could attract new investors, which in turn can help push the stock price further up.
#
# In conclusion, based on its upwardly trending stock price, solid industry position and positive market sentiment, TSLA squarely deserves to be considered for investment.
# bearish_research_agent: While it is true that Tesla's (TSLA) stock has shown growth over time, we should caution against viewing this particular pattern as an indicator of future performance. The recent increase, from $120 to $130, may simply be a part of short-term fluctuations rather than a consistent pattern of growth which can lead to unsustainable valuations.
#
# Additionally, while Tesla is a recognized entity in the technology industry, it is also part of the highly competitive and quickly evolving electric vehicle market. Their success is dependent on continual innovations and updates, an area fraught with uncertainties. Therefore, the need to stay ahead of competition can result in significant R&D costs which could affect future profitability.
#
# The mixed social media sentiments suggest a divided public opinion towards the company's prospects. While it may be trending positively now, the volatile nature of social media sentiment means this could quickly change and impact the stock's performance.
#
# While Tesla has a history of resilience, it should not be overlooked that they operate in a sector marked by rapid technological change, strict regulatory requirements and substantial capital demands. All these factors combined make TSLA a high risk investment.
#
# In conclusion, while the recent performance and positive sentiment may seem enticing, investors should remain cautious due to the risk factors associated with technological dependency, harsh competition, and unpredictable social media sentiment. It is crucial for potential investors to do a thorough analysis considering all factors before making a decision based on short-term growth trends.
#
# Trader's Decision:
# BUY
#
# The bullish argument presents strong points for considering an investment in Tesla (TSLA). The continuous growth in stock price is encouraging and a sign of good management and a promising future. While the bearish argument cautions against uncertainty due to the nature of the tech business and the volatility of social sentiments, it does not provide solid evidence of imminent declines or issues that could affect TSLA's current performance significantly. The positive trend in social media sentiment, while not a concrete indicator in itself, can contribute to potential investors' confidence. Therefore, if we consider the factors at hand, the bullish argument to continue investing in TSLA is stronger.
#
# Risk Management Team's Decision:
# APPROVED (Neutral)
#
# Should we execute the trade?
#
# --------------------------------------------------------------------------------
# manager_agent (to trade_recommender_agent):
#
# EXECUTE_TRADE
#
# The trade should be executed because of the following reasons:
#
# 1. Upward Trend: TSLA's stock price has been following an upward trend which showcases the stock's growth potential.
#
# 2. Position in Industry: TSLA is a well-recognized company in the tech industry which is rapidly growing. As the company has been founded in 2005, it implies good management and a solid business model as it has survived different economic climates.
#
# 3. Positive Social Sentiment: Though the social media sentiment is mixed, it is leaning towards positive which can help in boosting the stock performance.
#
# The bullish argument for investing in TSLA is more compelling considering the above information. The risk management team has also approved the trade. But the investor needs to be aware that stock prices can be volatile and can be affected by various factors. Therefore, it is essential to have a diversified portfolio to mitigate the risk.
#
# --------------------------------------------------------------------------------
# trade_recommender_agent (to manager_agent):
#
# FINISHED
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ea29a306-966b-430e-afeb-b367a8573be4): Termination message condition on agent 'manager_agent' met

# %%
import yfinance as yf
data = yf.download("AAPL", start="2020-01-01", end="2023-12-31")

print(data)

# %%
import tempfile

from autogen_core import SingleThreadedAgentRuntime
from autogen_ext.code_executors.docker import DockerCommandLineCodeExecutor
from autogen_ext.models.openai import OpenAIChatCompletionClient

work_dir = tempfile.mkdtemp()

# Create an local embedded runtime.
runtime = SingleThreadedAgentRuntime()

async with DockerCommandLineCodeExecutor(work_dir=work_dir) as executor:  # type: ignore[syntax]
    # Register the assistant and executor agents by providing
    # their agent types, the factory functions for creating instance and subscriptions.
    model_client = OpenAIChatCompletionClient(
        model="gpt-4o",
        api_key=OPENAI_API_KEY
    )
    await Assistant.register(
        runtime,
        "assistant",
        lambda: Assistant(model_client=model_client),
    )
    await Executor.register(runtime, "executor", lambda: Executor(executor))

    # Start the runtime and publish a message to the assistant.
    runtime.start()
    await runtime.publish_message(
        Message("Create a plot of NVIDA vs TSLA stock returns YTD from 2024-01-01."), DefaultTopicId()
    )

    # Wait for the runtime to stop when idle.
    await runtime.stop_when_idle()
    # Close the connection to the model client.
    await model_client.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\Anaconda\envs\myautogen\lib\site-packages\autogen_ext\code_executors\docker\_docker_code_executor.py:329, in DockerCommandLineCodeExecutor.start(self)
#     328 try:
# --> 329     import asyncio_atexit
#     331     import docker
#
# ModuleNotFoundError: No module named 'asyncio_atexit'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 12
#       9 # Create an local embedded runtime.
#      10 runtime = SingleThreadedAgentRuntime()
# ---> 12 async with DockerCommandLineCodeExecutor(work_dir=work_dir) as executor:  # type: ignore[syntax]
#      13     # Register the assistant and executor agents by providing
#      14     # their agent types, the factory functions for creating instance and subscriptions.
#      15     model_client = OpenAIChatCompletionClient(
#      16         model="gpt-4o",
#      17         api_key=OPENAI_API_KEY
#      18     )
#      19     await Assistant.register(
#      20         runtime,
#      21         "assistant",
#      22         lambda: Assistant(model_client=model_client),
#      23     )
#
# File d:\Anaconda\envs\myautogen\lib\site-packages\autogen_ext\code_executors\docker\_docker_code_executor.py:387, in DockerCommandLineCodeExecutor.__aenter__(self)
#     386 async def __aenter__(self) -> Self:
# --> 387     await self.start()
#     388     return self
#
# File d:\Anaconda\envs\myautogen\lib\site-packages\autogen_ext\code_executors\docker\_docker_code_executor.py:334, in DockerCommandLineCodeExecutor.start(self)
#     332     from docker.errors import DockerException, ImageNotFound
#     333 except ImportError as e:
# --> 334     raise RuntimeError(
#     335         "Missing dependecies for DockerCommandLineCodeExecutor. Please ensure the autogen-ext package was installed with the 'docker' extra."
#     336     ) from e
#     338 # Start a container from the image, read to exec commands later
#     339 try:
#
# RuntimeError: Missing dependecies for DockerCommandLineCodeExecutor. Please ensure the autogen-ext package was installed with the 'docker' extra.
